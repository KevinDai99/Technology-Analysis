# %%
import pandas as pd
import numpy as np
import yfinance as yf
import time 
import matplotlib.pyplot as plt

# %%
sp500 = pd.read_csv("Resources/sp500.csv")

# %%
combine = sp500.copy()

# %%
### Creation of Empty Columns to iterrow

combine["Price/Book"] = ""
combine["PEG Ratio"] = ""
combine["Foward PE"] = ""
combine["Trailing PE"] = ""
combine["Total Debt/Equity"] = ""
combine["EV/EBITDA"] = ""

for index, row in combine.iterrows():
    
    try:
    
        symbol = yf.Ticker(combine.loc[index, "Symbol"])
    
        print(f"Commence Extraction of {symbol} data")
        time.sleep(2)
        info = symbol.info
        combine.loc[index, "Price/Book"] = info["priceToBook"]
        combine.loc[index, "PEG Ratio"] = info["pegRatio"]
        combine.loc[index, "Foward PE"] = info["forwardPE"]
        combine.loc[index, "Trailing PE"] = info["trailingPE"]
        combine.loc[index, "EV/EBITDA"] = info["enterpriseToEbitda"]
        combine.loc[index, "Total Debt/Equity"] = info["debtToEquity"]
        
        
    except Exception:
        print(f"{symbol} not found")
# Out:
# Commence Extraction of yfinance.Ticker object <MMM> data
# Commence Extraction of yfinance.Ticker object <AOS> data
# Commence Extraction of yfinance.Ticker object <ABT> data
# Commence Extraction of yfinance.Ticker object <ABBV> data
# Commence Extraction of yfinance.Ticker object <ABMD> data
# Commence Extraction of yfinance.Ticker object <ACN> data
# Commence Extraction of yfinance.Ticker object <ATVI> data
# Commence Extraction of yfinance.Ticker object <ADM> data
# Commence Extraction of yfinance.Ticker object <ADBE> data
# Commence Extraction of yfinance.Ticker object <AAP> data
# Commence Extraction of yfinance.Ticker object <AMD> data
# Commence Extraction of yfinance.Ticker object <AES> data
# yfinance.Ticker object <AES> not found
# Commence Extraction of yfinance.Ticker object <AFL> data
# Commence Extraction of yfinance.Ticker object <A> data
# Commence Extraction of yfinance.Ticker object <APD> data
# Commence Extraction of yfinance.Ticker object <AKAM> data
# Commence Extraction of yfinance.Ticker object <ALK> data
# Commence Extraction of yfinance.Ticker object <ALB> data
# Commence Extraction of yfinance.Ticker object <ARE> data
# Commence Extraction of yfinance.Ticker object <ALGN> data
# Commence Extraction of yfinance.Ticker object <ALLE> data
# Commence Extraction of yfinance.Ticker object <LNT> data
# Commence Extraction of yfinance.Ticker object <ALL> data
# Commence Extraction of yfinance.Ticker object <GOOGL> data
# Commence Extraction of yfinance.Ticker object <GOOG> data
# Commence Extraction of yfinance.Ticker object <MO> data
# Commence Extraction of yfinance.Ticker object <AMZN> data
# Commence Extraction of yfinance.Ticker object <AMCR> data
# Commence Extraction of yfinance.Ticker object <AEE> data
# Commence Extraction of yfinance.Ticker object <AAL> data
# yfinance.Ticker object <AAL> not found
# Commence Extraction of yfinance.Ticker object <AEP> data
# Commence Extraction of yfinance.Ticker object <AXP> data
# Commence Extraction of yfinance.Ticker object <AIG> data
# Commence Extraction of yfinance.Ticker object <AMT> data
# Commence Extraction of yfinance.Ticker object <AWK> data
# Commence Extraction of yfinance.Ticker object <AMP> data
# Commence Extraction of yfinance.Ticker object <ABC> data
# Commence Extraction of yfinance.Ticker object <AME> data
# Commence Extraction of yfinance.Ticker object <AMGN> data
# Commence Extraction of yfinance.Ticker object <APH> data
# Commence Extraction of yfinance.Ticker object <ADI> data
# Commence Extraction of yfinance.Ticker object <ANSS> data
# Commence Extraction of yfinance.Ticker object <ANTM> data
# yfinance.Ticker object <ANTM> not found
# Commence Extraction of yfinance.Ticker object <AON> data
# Commence Extraction of yfinance.Ticker object <APA> data
# Commence Extraction of yfinance.Ticker object <AAPL> data
# Commence Extraction of yfinance.Ticker object <AMAT> data
# Commence Extraction of yfinance.Ticker object <APTV> data
# Commence Extraction of yfinance.Ticker object <ANET> data
# Commence Extraction of yfinance.Ticker object <AJG> data
# Commence Extraction of yfinance.Ticker object <AIZ> data
# Commence Extraction of yfinance.Ticker object <T> data
# Commence Extraction of yfinance.Ticker object <ATO> data
# Commence Extraction of yfinance.Ticker object <ADSK> data
# Commence Extraction of yfinance.Ticker object <ADP> data
# Commence Extraction of yfinance.Ticker object <AZO> data
# Commence Extraction of yfinance.Ticker object <AVB> data
# Commence Extraction of yfinance.Ticker object <AVY> data
# Commence Extraction of yfinance.Ticker object <BKR> data
# Commence Extraction of yfinance.Ticker object <BLL> data
# yfinance.Ticker object <BLL> not found
# Commence Extraction of yfinance.Ticker object <BAC> data
# Commence Extraction of yfinance.Ticker object <BBWI> data
# Commence Extraction of yfinance.Ticker object <BAX> data
# Commence Extraction of yfinance.Ticker object <BDX> data
# Commence Extraction of yfinance.Ticker object <BRK.B> data
# yfinance.Ticker object <BRK.B> not found
# Commence Extraction of yfinance.Ticker object <BBY> data
# Commence Extraction of yfinance.Ticker object <BIO> data
# yfinance.Ticker object <BIO> not found
# Commence Extraction of yfinance.Ticker object <TECH> data
# Commence Extraction of yfinance.Ticker object <BIIB> data
# Commence Extraction of yfinance.Ticker object <BLK> data
# Commence Extraction of yfinance.Ticker object <BK> data
# Commence Extraction of yfinance.Ticker object <BA> data
# yfinance.Ticker object <BA> not found
# Commence Extraction of yfinance.Ticker object <BKNG> data
# Commence Extraction of yfinance.Ticker object <BWA> data
# Commence Extraction of yfinance.Ticker object <BXP> data
# Commence Extraction of yfinance.Ticker object <BSX> data
# Commence Extraction of yfinance.Ticker object <BMY> data
# Commence Extraction of yfinance.Ticker object <AVGO> data
# Commence Extraction of yfinance.Ticker object <BR> data
# Commence Extraction of yfinance.Ticker object <BRO> data
# Commence Extraction of yfinance.Ticker object <BF.B> data
# yfinance.Ticker object <BF.B> not found
# Commence Extraction of yfinance.Ticker object <CHRW> data
# Commence Extraction of yfinance.Ticker object <CDNS> data
# Commence Extraction of yfinance.Ticker object <CZR> data
# yfinance.Ticker object <CZR> not found
# Commence Extraction of yfinance.Ticker object <CPB> data
# Commence Extraction of yfinance.Ticker object <COF> data
# Commence Extraction of yfinance.Ticker object <CAH> data
# yfinance.Ticker object <CAH> not found
# Commence Extraction of yfinance.Ticker object <KMX> data
# Commence Extraction of yfinance.Ticker object <CCL> data
# yfinance.Ticker object <CCL> not found
# Commence Extraction of yfinance.Ticker object <CARR> data
# Commence Extraction of yfinance.Ticker object <CTLT> data
# Commence Extraction of yfinance.Ticker object <CAT> data
# Commence Extraction of yfinance.Ticker object <CBOE> data
# Commence Extraction of yfinance.Ticker object <CBRE> data
# Commence Extraction of yfinance.Ticker object <CDW> data
# Commence Extraction of yfinance.Ticker object <CE> data
# Commence Extraction of yfinance.Ticker object <CNC> data
# Commence Extraction of yfinance.Ticker object <CNP> data
# Commence Extraction of yfinance.Ticker object <CDAY> data
# yfinance.Ticker object <CDAY> not found
# Commence Extraction of yfinance.Ticker object <CERN> data
# yfinance.Ticker object <CERN> not found
# Commence Extraction of yfinance.Ticker object <CF> data
# Commence Extraction of yfinance.Ticker object <CRL> data
# Commence Extraction of yfinance.Ticker object <SCHW> data
# Commence Extraction of yfinance.Ticker object <CHTR> data
# Commence Extraction of yfinance.Ticker object <CVX> data
# Commence Extraction of yfinance.Ticker object <CMG> data
# Commence Extraction of yfinance.Ticker object <CB> data
# Commence Extraction of yfinance.Ticker object <CHD> data
# Commence Extraction of yfinance.Ticker object <CI> data
# Commence Extraction of yfinance.Ticker object <CINF> data
# Commence Extraction of yfinance.Ticker object <CTAS> data
# Commence Extraction of yfinance.Ticker object <CSCO> data
# Commence Extraction of yfinance.Ticker object <C> data
# Commence Extraction of yfinance.Ticker object <CFG> data
# Commence Extraction of yfinance.Ticker object <CTXS> data
# yfinance.Ticker object <CTXS> not found
# Commence Extraction of yfinance.Ticker object <CLX> data
# Commence Extraction of yfinance.Ticker object <CME> data
# Commence Extraction of yfinance.Ticker object <CMS> data
# Commence Extraction of yfinance.Ticker object <KO> data
# Commence Extraction of yfinance.Ticker object <CTSH> data
# Commence Extraction of yfinance.Ticker object <CL> data
# Commence Extraction of yfinance.Ticker object <CMCSA> data
# Commence Extraction of yfinance.Ticker object <CMA> data
# Commence Extraction of yfinance.Ticker object <CAG> data
# Commence Extraction of yfinance.Ticker object <COP> data
# Commence Extraction of yfinance.Ticker object <ED> data
# Commence Extraction of yfinance.Ticker object <STZ> data
# Commence Extraction of yfinance.Ticker object <CPRT> data
# Commence Extraction of yfinance.Ticker object <GLW> data
# Commence Extraction of yfinance.Ticker object <CTVA> data
# Commence Extraction of yfinance.Ticker object <COST> data
# Commence Extraction of yfinance.Ticker object <CTRA> data
# Commence Extraction of yfinance.Ticker object <CCI> data
# Commence Extraction of yfinance.Ticker object <CSX> data
# Commence Extraction of yfinance.Ticker object <CMI> data
# Commence Extraction of yfinance.Ticker object <CVS> data
# Commence Extraction of yfinance.Ticker object <DHI> data
# Commence Extraction of yfinance.Ticker object <DHR> data
# Commence Extraction of yfinance.Ticker object <DRI> data
# Commence Extraction of yfinance.Ticker object <DVA> data
# Commence Extraction of yfinance.Ticker object <DE> data
# Commence Extraction of yfinance.Ticker object <DAL> data
# Commence Extraction of yfinance.Ticker object <XRAY> data
# Commence Extraction of yfinance.Ticker object <DVN> data
# Commence Extraction of yfinance.Ticker object <DXCM> data
# Commence Extraction of yfinance.Ticker object <FANG> data
# Commence Extraction of yfinance.Ticker object <DLR> data
# Commence Extraction of yfinance.Ticker object <DFS> data
# Commence Extraction of yfinance.Ticker object <DISCA> data
# yfinance.Ticker object <DISCA> not found
# Commence Extraction of yfinance.Ticker object <DISCK> data
# yfinance.Ticker object <DISCK> not found
# Commence Extraction of yfinance.Ticker object <DISH> data
# Commence Extraction of yfinance.Ticker object <DG> data
# Commence Extraction of yfinance.Ticker object <DLTR> data
# Commence Extraction of yfinance.Ticker object <D> data
# Commence Extraction of yfinance.Ticker object <DPZ> data
# Commence Extraction of yfinance.Ticker object <DOV> data
# Commence Extraction of yfinance.Ticker object <DOW> data
# Commence Extraction of yfinance.Ticker object <DTE> data
# Commence Extraction of yfinance.Ticker object <DUK> data
# Commence Extraction of yfinance.Ticker object <DRE> data
# Commence Extraction of yfinance.Ticker object <DD> data
# Commence Extraction of yfinance.Ticker object <DXC> data
# Commence Extraction of yfinance.Ticker object <EMN> data
# Commence Extraction of yfinance.Ticker object <ETN> data
# Commence Extraction of yfinance.Ticker object <EBAY> data
# Commence Extraction of yfinance.Ticker object <ECL> data
# Commence Extraction of yfinance.Ticker object <EIX> data
# Commence Extraction of yfinance.Ticker object <EW> data
# Commence Extraction of yfinance.Ticker object <EA> data
# Commence Extraction of yfinance.Ticker object <LLY> data
# Commence Extraction of yfinance.Ticker object <EMR> data
# Commence Extraction of yfinance.Ticker object <ENPH> data
# Commence Extraction of yfinance.Ticker object <ETR> data
# Commence Extraction of yfinance.Ticker object <EOG> data
# Commence Extraction of yfinance.Ticker object <EFX> data
# Commence Extraction of yfinance.Ticker object <EQIX> data
# Commence Extraction of yfinance.Ticker object <EQR> data
# Commence Extraction of yfinance.Ticker object <ESS> data
# Commence Extraction of yfinance.Ticker object <EL> data
# Commence Extraction of yfinance.Ticker object <ETSY> data
# Commence Extraction of yfinance.Ticker object <RE> data
# Commence Extraction of yfinance.Ticker object <EVRG> data
# Commence Extraction of yfinance.Ticker object <ES> data
# Commence Extraction of yfinance.Ticker object <EXC> data
# Commence Extraction of yfinance.Ticker object <EXPE> data
# Commence Extraction of yfinance.Ticker object <EXPD> data
# Commence Extraction of yfinance.Ticker object <EXR> data
# Commence Extraction of yfinance.Ticker object <XOM> data
# Commence Extraction of yfinance.Ticker object <FFIV> data
# Commence Extraction of yfinance.Ticker object <FB> data
# Commence Extraction of yfinance.Ticker object <FAST> data
# Commence Extraction of yfinance.Ticker object <FRT> data
# Commence Extraction of yfinance.Ticker object <FDX> data
# Commence Extraction of yfinance.Ticker object <FIS> data
# Commence Extraction of yfinance.Ticker object <FITB> data
# Commence Extraction of yfinance.Ticker object <FRC> data
# Commence Extraction of yfinance.Ticker object <FE> data
# Commence Extraction of yfinance.Ticker object <FISV> data
# Commence Extraction of yfinance.Ticker object <FLT> data
# Commence Extraction of yfinance.Ticker object <FMC> data
# Commence Extraction of yfinance.Ticker object <F> data
# Commence Extraction of yfinance.Ticker object <FTNT> data
# Commence Extraction of yfinance.Ticker object <FTV> data
# Commence Extraction of yfinance.Ticker object <FBHS> data
# Commence Extraction of yfinance.Ticker object <FOXA> data
# Commence Extraction of yfinance.Ticker object <FOX> data
# Commence Extraction of yfinance.Ticker object <BEN> data
# Commence Extraction of yfinance.Ticker object <FCX> data
# Commence Extraction of yfinance.Ticker object <GPS> data
# yfinance.Ticker object <GPS> not found
# Commence Extraction of yfinance.Ticker object <GRMN> data
# Commence Extraction of yfinance.Ticker object <IT> data
# Commence Extraction of yfinance.Ticker object <GNRC> data
# Commence Extraction of yfinance.Ticker object <GD> data
# Commence Extraction of yfinance.Ticker object <GE> data
# yfinance.Ticker object <GE> not found
# Commence Extraction of yfinance.Ticker object <GIS> data
# Commence Extraction of yfinance.Ticker object <GM> data
# Commence Extraction of yfinance.Ticker object <GPC> data
# Commence Extraction of yfinance.Ticker object <GILD> data
# Commence Extraction of yfinance.Ticker object <GPN> data
# Commence Extraction of yfinance.Ticker object <GL> data
# Commence Extraction of yfinance.Ticker object <GS> data
# Commence Extraction of yfinance.Ticker object <HAL> data
# yfinance.Ticker object <HAL> not found
# Commence Extraction of yfinance.Ticker object <HBI> data
# yfinance.Ticker object <HBI> not found
# Commence Extraction of yfinance.Ticker object <HAS> data
# Commence Extraction of yfinance.Ticker object <HCA> data
# Commence Extraction of yfinance.Ticker object <PEAK> data
# Commence Extraction of yfinance.Ticker object <HSIC> data
# Commence Extraction of yfinance.Ticker object <HES> data
# yfinance.Ticker object <HES> not found
# Commence Extraction of yfinance.Ticker object <HPE> data
# yfinance.Ticker object <HPE> not found
# Commence Extraction of yfinance.Ticker object <HLT> data
# yfinance.Ticker object <HLT> not found
# Commence Extraction of yfinance.Ticker object <HOLX> data
# Commence Extraction of yfinance.Ticker object <HD> data
# Commence Extraction of yfinance.Ticker object <HON> data
# Commence Extraction of yfinance.Ticker object <HRL> data
# Commence Extraction of yfinance.Ticker object <HST> data
# yfinance.Ticker object <HST> not found
# Commence Extraction of yfinance.Ticker object <HWM> data
# Commence Extraction of yfinance.Ticker object <HPQ> data
# Commence Extraction of yfinance.Ticker object <HUM> data
# Commence Extraction of yfinance.Ticker object <HBAN> data
# Commence Extraction of yfinance.Ticker object <HII> data
# Commence Extraction of yfinance.Ticker object <IBM> data
# Commence Extraction of yfinance.Ticker object <IEX> data
# Commence Extraction of yfinance.Ticker object <IDXX> data
# Commence Extraction of yfinance.Ticker object <INFO> data
# yfinance.Ticker object <INFO> not found
# Commence Extraction of yfinance.Ticker object <ITW> data
# Commence Extraction of yfinance.Ticker object <ILMN> data
# Commence Extraction of yfinance.Ticker object <INCY> data
# yfinance.Ticker object <INCY> not found
# Commence Extraction of yfinance.Ticker object <IR> data
# yfinance.Ticker object <IR> not found
# Commence Extraction of yfinance.Ticker object <INTC> data
# Commence Extraction of yfinance.Ticker object <ICE> data
# Commence Extraction of yfinance.Ticker object <IFF> data
# Commence Extraction of yfinance.Ticker object <IP> data
# Commence Extraction of yfinance.Ticker object <IPG> data
# Commence Extraction of yfinance.Ticker object <INTU> data
# Commence Extraction of yfinance.Ticker object <ISRG> data
# Commence Extraction of yfinance.Ticker object <IVZ> data
# Commence Extraction of yfinance.Ticker object <IPGP> data
# Commence Extraction of yfinance.Ticker object <IQV> data
# Commence Extraction of yfinance.Ticker object <IRM> data
# Commence Extraction of yfinance.Ticker object <JBHT> data
# Commence Extraction of yfinance.Ticker object <JKHY> data
# Commence Extraction of yfinance.Ticker object <J> data
# Commence Extraction of yfinance.Ticker object <SJM> data
# Commence Extraction of yfinance.Ticker object <JNJ> data
# Commence Extraction of yfinance.Ticker object <JCI> data
# Commence Extraction of yfinance.Ticker object <JPM> data
# Commence Extraction of yfinance.Ticker object <JNPR> data
# Commence Extraction of yfinance.Ticker object <KSU> data
# yfinance.Ticker object <KSU> not found
# Commence Extraction of yfinance.Ticker object <K> data
# Commence Extraction of yfinance.Ticker object <KEY> data
# Commence Extraction of yfinance.Ticker object <KEYS> data
# Commence Extraction of yfinance.Ticker object <KMB> data
# Commence Extraction of yfinance.Ticker object <KIM> data
# Commence Extraction of yfinance.Ticker object <KMI> data
# Commence Extraction of yfinance.Ticker object <KLAC> data
# Commence Extraction of yfinance.Ticker object <KHC> data
# Commence Extraction of yfinance.Ticker object <KR> data
# Commence Extraction of yfinance.Ticker object <LHX> data
# Commence Extraction of yfinance.Ticker object <LH> data
# Commence Extraction of yfinance.Ticker object <LRCX> data
# Commence Extraction of yfinance.Ticker object <LW> data
# Commence Extraction of yfinance.Ticker object <LVS> data
# yfinance.Ticker object <LVS> not found
# Commence Extraction of yfinance.Ticker object <LEG> data
# Commence Extraction of yfinance.Ticker object <LDOS> data
# Commence Extraction of yfinance.Ticker object <LEN> data
# Commence Extraction of yfinance.Ticker object <LNC> data
# Commence Extraction of yfinance.Ticker object <LIN> data
# Commence Extraction of yfinance.Ticker object <LYV> data
# yfinance.Ticker object <LYV> not found
# Commence Extraction of yfinance.Ticker object <LKQ> data
# Commence Extraction of yfinance.Ticker object <LMT> data
# Commence Extraction of yfinance.Ticker object <L> data
# yfinance.Ticker object <L> not found
# Commence Extraction of yfinance.Ticker object <LOW> data
# Commence Extraction of yfinance.Ticker object <LUMN> data
# yfinance.Ticker object <LUMN> not found
# Commence Extraction of yfinance.Ticker object <LYB> data
# Commence Extraction of yfinance.Ticker object <MTB> data
# Commence Extraction of yfinance.Ticker object <MRO> data
# yfinance.Ticker object <MRO> not found
# Commence Extraction of yfinance.Ticker object <MPC> data
# yfinance.Ticker object <MPC> not found
# Commence Extraction of yfinance.Ticker object <MKTX> data
# Commence Extraction of yfinance.Ticker object <MAR> data
# yfinance.Ticker object <MAR> not found
# Commence Extraction of yfinance.Ticker object <MMC> data
# Commence Extraction of yfinance.Ticker object <MLM> data
# Commence Extraction of yfinance.Ticker object <MAS> data
# Commence Extraction of yfinance.Ticker object <MA> data
# Commence Extraction of yfinance.Ticker object <MTCH> data
# Commence Extraction of yfinance.Ticker object <MKC> data
# Commence Extraction of yfinance.Ticker object <MCD> data
# Commence Extraction of yfinance.Ticker object <MCK> data
# yfinance.Ticker object <MCK> not found
# Commence Extraction of yfinance.Ticker object <MDT> data
# Commence Extraction of yfinance.Ticker object <MRK> data
# Commence Extraction of yfinance.Ticker object <MET> data
# Commence Extraction of yfinance.Ticker object <MTD> data
# Commence Extraction of yfinance.Ticker object <MGM> data
# yfinance.Ticker object <MGM> not found
# Commence Extraction of yfinance.Ticker object <MCHP> data
# Commence Extraction of yfinance.Ticker object <MU> data
# Commence Extraction of yfinance.Ticker object <MSFT> data
# Commence Extraction of yfinance.Ticker object <MAA> data
# Commence Extraction of yfinance.Ticker object <MRNA> data
# yfinance.Ticker object <MRNA> not found
# Commence Extraction of yfinance.Ticker object <MHK> data
# Commence Extraction of yfinance.Ticker object <TAP> data
# yfinance.Ticker object <TAP> not found
# Commence Extraction of yfinance.Ticker object <MDLZ> data
# Commence Extraction of yfinance.Ticker object <MPWR> data
# Commence Extraction of yfinance.Ticker object <MNST> data
# Commence Extraction of yfinance.Ticker object <MCO> data
# Commence Extraction of yfinance.Ticker object <MS> data
# Commence Extraction of yfinance.Ticker object <MSI> data
# Commence Extraction of yfinance.Ticker object <MSCI> data
# Commence Extraction of yfinance.Ticker object <NDAQ> data
# Commence Extraction of yfinance.Ticker object <NTAP> data
# Commence Extraction of yfinance.Ticker object <NFLX> data
# Commence Extraction of yfinance.Ticker object <NWL> data
# Commence Extraction of yfinance.Ticker object <NEM> data
# Commence Extraction of yfinance.Ticker object <NWSA> data
# yfinance.Ticker object <NWSA> not found
# Commence Extraction of yfinance.Ticker object <NWS> data
# yfinance.Ticker object <NWS> not found
# Commence Extraction of yfinance.Ticker object <NEE> data
# Commence Extraction of yfinance.Ticker object <NLSN> data
# yfinance.Ticker object <NLSN> not found
# Commence Extraction of yfinance.Ticker object <NKE> data
# Commence Extraction of yfinance.Ticker object <NI> data
# yfinance.Ticker object <NI> not found
# Commence Extraction of yfinance.Ticker object <NSC> data
# Commence Extraction of yfinance.Ticker object <NTRS> data
# Commence Extraction of yfinance.Ticker object <NOC> data
# Commence Extraction of yfinance.Ticker object <NLOK> data
# Commence Extraction of yfinance.Ticker object <NCLH> data
# yfinance.Ticker object <NCLH> not found
# Commence Extraction of yfinance.Ticker object <NRG> data
# Commence Extraction of yfinance.Ticker object <NUE> data
# Commence Extraction of yfinance.Ticker object <NVDA> data
# Commence Extraction of yfinance.Ticker object <NVR> data
# Commence Extraction of yfinance.Ticker object <NXPI> data
# Commence Extraction of yfinance.Ticker object <ORLY> data
# Commence Extraction of yfinance.Ticker object <OXY> data
# yfinance.Ticker object <OXY> not found
# Commence Extraction of yfinance.Ticker object <ODFL> data
# Commence Extraction of yfinance.Ticker object <OMC> data
# Commence Extraction of yfinance.Ticker object <OKE> data
# Commence Extraction of yfinance.Ticker object <ORCL> data
# Commence Extraction of yfinance.Ticker object <OGN> data
# yfinance.Ticker object <OGN> not found
# Commence Extraction of yfinance.Ticker object <OTIS> data
# Commence Extraction of yfinance.Ticker object <PCAR> data
# Commence Extraction of yfinance.Ticker object <PKG> data
# Commence Extraction of yfinance.Ticker object <PH> data
# Commence Extraction of yfinance.Ticker object <PAYX> data
# Commence Extraction of yfinance.Ticker object <PAYC> data
# Commence Extraction of yfinance.Ticker object <PYPL> data
# Commence Extraction of yfinance.Ticker object <PENN> data
# yfinance.Ticker object <PENN> not found
# Commence Extraction of yfinance.Ticker object <PNR> data
# Commence Extraction of yfinance.Ticker object <PBCT> data
# yfinance.Ticker object <PBCT> not found
# Commence Extraction of yfinance.Ticker object <PEP> data
# Commence Extraction of yfinance.Ticker object <PKI> data
# Commence Extraction of yfinance.Ticker object <PFE> data
# Commence Extraction of yfinance.Ticker object <PM> data
# Commence Extraction of yfinance.Ticker object <PSX> data
# yfinance.Ticker object <PSX> not found
# Commence Extraction of yfinance.Ticker object <PNW> data
# Commence Extraction of yfinance.Ticker object <PXD> data
# yfinance.Ticker object <PXD> not found
# Commence Extraction of yfinance.Ticker object <PNC> data
# Commence Extraction of yfinance.Ticker object <POOL> data
# Commence Extraction of yfinance.Ticker object <PPG> data
# Commence Extraction of yfinance.Ticker object <PPL> data
# Commence Extraction of yfinance.Ticker object <PFG> data
# Commence Extraction of yfinance.Ticker object <PG> data
# Commence Extraction of yfinance.Ticker object <PGR> data
# Commence Extraction of yfinance.Ticker object <PLD> data
# Commence Extraction of yfinance.Ticker object <PRU> data
# yfinance.Ticker object <PRU> not found
# Commence Extraction of yfinance.Ticker object <PTC> data
# Commence Extraction of yfinance.Ticker object <PEG> data
# Commence Extraction of yfinance.Ticker object <PSA> data
# Commence Extraction of yfinance.Ticker object <PHM> data
# Commence Extraction of yfinance.Ticker object <PVH> data
# yfinance.Ticker object <PVH> not found
# Commence Extraction of yfinance.Ticker object <QRVO> data
# Commence Extraction of yfinance.Ticker object <QCOM> data
# Commence Extraction of yfinance.Ticker object <PWR> data
# Commence Extraction of yfinance.Ticker object <DGX> data
# Commence Extraction of yfinance.Ticker object <RL> data
# yfinance.Ticker object <RL> not found
# Commence Extraction of yfinance.Ticker object <RJF> data
# Commence Extraction of yfinance.Ticker object <RTX> data
# Commence Extraction of yfinance.Ticker object <O> data
# Commence Extraction of yfinance.Ticker object <REG> data
# Commence Extraction of yfinance.Ticker object <REGN> data
# Commence Extraction of yfinance.Ticker object <RF> data
# Commence Extraction of yfinance.Ticker object <RSG> data
# Commence Extraction of yfinance.Ticker object <RMD> data
# Commence Extraction of yfinance.Ticker object <RHI> data
# Commence Extraction of yfinance.Ticker object <ROK> data
# Commence Extraction of yfinance.Ticker object <ROL> data
# Commence Extraction of yfinance.Ticker object <ROP> data
# Commence Extraction of yfinance.Ticker object <ROST> data
# Commence Extraction of yfinance.Ticker object <RCL> data
# yfinance.Ticker object <RCL> not found
# Commence Extraction of yfinance.Ticker object <SPGI> data
# Commence Extraction of yfinance.Ticker object <CRM> data
# Commence Extraction of yfinance.Ticker object <SBAC> data
# Commence Extraction of yfinance.Ticker object <SLB> data
# yfinance.Ticker object <SLB> not found
# Commence Extraction of yfinance.Ticker object <STX> data
# Commence Extraction of yfinance.Ticker object <SEE> data
# Commence Extraction of yfinance.Ticker object <SRE> data
# Commence Extraction of yfinance.Ticker object <NOW> data
# Commence Extraction of yfinance.Ticker object <SHW> data
# Commence Extraction of yfinance.Ticker object <SPG> data
# Commence Extraction of yfinance.Ticker object <SWKS> data
# Commence Extraction of yfinance.Ticker object <SNA> data
# Commence Extraction of yfinance.Ticker object <SO> data
# Commence Extraction of yfinance.Ticker object <LUV> data
# yfinance.Ticker object <LUV> not found
# Commence Extraction of yfinance.Ticker object <SWK> data
# Commence Extraction of yfinance.Ticker object <SBUX> data
# Commence Extraction of yfinance.Ticker object <STT> data
# Commence Extraction of yfinance.Ticker object <STE> data
# Commence Extraction of yfinance.Ticker object <SYK> data
# Commence Extraction of yfinance.Ticker object <SIVB> data
# Commence Extraction of yfinance.Ticker object <SYF> data
# Commence Extraction of yfinance.Ticker object <SNPS> data
# Commence Extraction of yfinance.Ticker object <SYY> data
# yfinance.Ticker object <SYY> not found
# Commence Extraction of yfinance.Ticker object <TMUS> data
# Commence Extraction of yfinance.Ticker object <TROW> data
# Commence Extraction of yfinance.Ticker object <TTWO> data
# Commence Extraction of yfinance.Ticker object <TPR> data
# yfinance.Ticker object <TPR> not found
# Commence Extraction of yfinance.Ticker object <TGT> data
# Commence Extraction of yfinance.Ticker object <TEL> data
# Commence Extraction of yfinance.Ticker object <TDY> data
# Commence Extraction of yfinance.Ticker object <TFX> data
# Commence Extraction of yfinance.Ticker object <TER> data
# Commence Extraction of yfinance.Ticker object <TSLA> data
# Commence Extraction of yfinance.Ticker object <TXN> data
# Commence Extraction of yfinance.Ticker object <TXT> data
# Commence Extraction of yfinance.Ticker object <COO> data
# Commence Extraction of yfinance.Ticker object <HIG> data
# Commence Extraction of yfinance.Ticker object <HSY> data
# Commence Extraction of yfinance.Ticker object <MOS> data
# Commence Extraction of yfinance.Ticker object <TRV> data
# Commence Extraction of yfinance.Ticker object <DIS> data
# yfinance.Ticker object <DIS> not found
# Commence Extraction of yfinance.Ticker object <TMO> data
# Commence Extraction of yfinance.Ticker object <TJX> data
# Commence Extraction of yfinance.Ticker object <TSCO> data
# Commence Extraction of yfinance.Ticker object <TT> data
# Commence Extraction of yfinance.Ticker object <TDG> data
# Commence Extraction of yfinance.Ticker object <TRMB> data
# Commence Extraction of yfinance.Ticker object <TFC> data
# Commence Extraction of yfinance.Ticker object <TWTR> data
# yfinance.Ticker object <TWTR> not found
# Commence Extraction of yfinance.Ticker object <TYL> data
# Commence Extraction of yfinance.Ticker object <TSN> data
# Commence Extraction of yfinance.Ticker object <USB> data
# Commence Extraction of yfinance.Ticker object <UDR> data
# Commence Extraction of yfinance.Ticker object <ULTA> data
# Commence Extraction of yfinance.Ticker object <UAA> data
# yfinance.Ticker object <UAA> not found
# Commence Extraction of yfinance.Ticker object <UA> data
# yfinance.Ticker object <UA> not found
# Commence Extraction of yfinance.Ticker object <UNP> data
# Commence Extraction of yfinance.Ticker object <UAL> data
# yfinance.Ticker object <UAL> not found
# Commence Extraction of yfinance.Ticker object <UPS> data
# Commence Extraction of yfinance.Ticker object <URI> data
# Commence Extraction of yfinance.Ticker object <UNH> data
# Commence Extraction of yfinance.Ticker object <UHS> data
# Commence Extraction of yfinance.Ticker object <VLO> data
# yfinance.Ticker object <VLO> not found
# Commence Extraction of yfinance.Ticker object <VTR> data
# Commence Extraction of yfinance.Ticker object <VRSN> data
# Commence Extraction of yfinance.Ticker object <VRSK> data
# Commence Extraction of yfinance.Ticker object <VZ> data
# Commence Extraction of yfinance.Ticker object <VRTX> data
# Commence Extraction of yfinance.Ticker object <VFC> data
# yfinance.Ticker object <VFC> not found
# Commence Extraction of yfinance.Ticker object <VIAC> data
# yfinance.Ticker object <VIAC> not found
# Commence Extraction of yfinance.Ticker object <VTRS> data
# yfinance.Ticker object <VTRS> not found
# Commence Extraction of yfinance.Ticker object <V> data
# Commence Extraction of yfinance.Ticker object <VNO> data
# yfinance.Ticker object <VNO> not found
# Commence Extraction of yfinance.Ticker object <VMC> data
# Commence Extraction of yfinance.Ticker object <WRB> data
# Commence Extraction of yfinance.Ticker object <GWW> data
# Commence Extraction of yfinance.Ticker object <WAB> data
# Commence Extraction of yfinance.Ticker object <WBA> data
# yfinance.Ticker object <WBA> not found
# Commence Extraction of yfinance.Ticker object <WMT> data
# Commence Extraction of yfinance.Ticker object <WM> data
# Commence Extraction of yfinance.Ticker object <WAT> data
# Commence Extraction of yfinance.Ticker object <WEC> data
# Commence Extraction of yfinance.Ticker object <WFC> data
# Commence Extraction of yfinance.Ticker object <WELL> data
# Commence Extraction of yfinance.Ticker object <WST> data
# Commence Extraction of yfinance.Ticker object <WDC> data
# Commence Extraction of yfinance.Ticker object <WU> data
# Commence Extraction of yfinance.Ticker object <WRK> data
# yfinance.Ticker object <WRK> not found
# Commence Extraction of yfinance.Ticker object <WY> data
# Commence Extraction of yfinance.Ticker object <WHR> data
# Commence Extraction of yfinance.Ticker object <WMB> data
# Commence Extraction of yfinance.Ticker object <WLTW> data
# yfinance.Ticker object <WLTW> not found
# Commence Extraction of yfinance.Ticker object <WYNN> data
# yfinance.Ticker object <WYNN> not found
# Commence Extraction of yfinance.Ticker object <XEL> data
# Commence Extraction of yfinance.Ticker object <XLNX> data
# yfinance.Ticker object <XLNX> not found
# Commence Extraction of yfinance.Ticker object <XYL> data
# Commence Extraction of yfinance.Ticker object <YUM> data
# Commence Extraction of yfinance.Ticker object <ZBRA> data
# Commence Extraction of yfinance.Ticker object <ZBH> data
# yfinance.Ticker object <ZBH> not found
# Commence Extraction of yfinance.Ticker object <ZION> data
# Commence Extraction of yfinance.Ticker object <ZTS> data

# %% [markdown]
# # Investigation: Is the Tech industry overvalued?
# ----
#
# ## 1. Explore Mutiple Valuation (Kevin)
#
# * Explore the Market Valuation vs intrinsic valuation of the Tech
# * Run ANOVA Test across various valuations
#
# ## 2. Financials of IT industry vs other Industry (Vincent)
#
# * Growth Rate
# * Equity/Debt
# * Profit Margins
# * Market Capitilization over time (Outstanding Shares * Share price over time)
#
#
# ## 3. Market Stock Trending of IT vs other Industries (Komal)
#
# * Market Volitility of industry vs other industries or historical
# * Percent Change over time of stocks vs other industries or historical
#
# ## 4. Sentimental Analysis of IT - Limitations, and Further Reseach opportunities (Kevin)
#
# * Twitter Tweet Analysis - download all the comments on twitter,and reactionts towards meta-verse, many upset privacy
# * Reddit API
# * Natural Language Process

# %%
combine.to_csv("Output/SummaryStockData.csv", index = False)

# %%
combine = pd.read_csv("Output/SummaryStockData.csv")

# %% [markdown]
# ### Boxplot of Valuation Ratios of various Industry

# %%
combine = combine.fillna(0)

# %%
mutiple = ['Price/Book', 'PEG Ratio', 'Foward PE', 'Trailing PE','EV/EBITDA']

# %%
combine[mutiple] = combine[combine[mutiple] > 0][mutiple]

# %%
#formating fliers 
flierprops = dict(marker='o', markerfacecolor='r', markersize=12,
                  linestyle='none', markeredgecolor='g')

combine.boxplot(column = "EV/EBITDA", by = "Sector", showfliers=False,
               grid = False, rot = 90)



plt.show()

# %% [markdown]
# ## For loop to extract Financials

# %%
symbols = combine["Symbol"].to_list()

# %%
list_of_df = []

print("Begin Extraction of Ticker")

for symbol in symbols:
    
    extract = yf.Ticker(symbol)
    financials = extract.financials
    financials = financials.transpose()
    importance = ["Net Income", "Other Operating Expenses", "Research Development", "Gross Profit"]
    
    isolate = financials[importance]
    
    isolate.loc[:,"Symbol"] = symbol 
    
    list_of_df.append(isolate)
    
    print(f"{symbol} has been extracted")

# %%
consolidated_financials = pd.concat(list_of_df, axis = 0)

# %%
for column in importance:
    consolidated_financials[column] = consolidated_financials[column].astype(str)
    consolidated_financials[column] = consolidated_financials[column].str.replace("None", '0')
    consolidated_financials[column] = consolidated_financials[column].astype(float)
